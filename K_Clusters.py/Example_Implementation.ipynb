# %% [markdown]
# # Install Packages and Libraries

# %%
# Install packages
# %pip install -U ipykernel matplotlib pandas

# Import libraries
from matplotlib import pyplot as plt
from pandas import read_csv
from random import choice, randint
from K_Clusters import K_Clusters # Import the kMeans model
# Out:
# Requirement already satisfied: ipykernel in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (6.29.5)
# Requirement already satisfied: matplotlib in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (3.10.0)
# Requirement already satisfied: pandas in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: comm>=0.1.1 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (1.8.9)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (8.30.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: pillow>=8 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: colorama in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.18.0)
# Requirement already satisfied: stack_data in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (308)
# Requirement already satisfied: six>=1.5 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\marion.forrest.nlplogix\documents\code\building-blocks-1\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load and Clean the Data

# %%
df = read_csv("iris.csv")
df.drop(columns=["species"], inplace=True)
matrix = (df.to_numpy().tolist())

# %% [markdown]
# # Train Models

# %%
# Initialize the models
groups = 3
models: list[K_Clusters] = [
    K_Clusters(
        trainingMatrix=matrix,
        kGroups=groups,
        distanceStrategy="euclidean",
        centroidStrategy="median"
        
    ),
    K_Clusters(
        trainingMatrix=matrix,
        kGroups=groups,
        distanceStrategy="euclidean",
        centroidStrategy="mean"
    ),
]

# Train the models
epochs = [
    model.Train() for model in models
]

# %% [markdown]
# # Graph Clusters
#
# *Colors are assigned randomly*

# %%
def Draw_Clusters(model: K_Clusters, axis: plt.Axes, epoch: int) -> None:
    print(f"\n{model.distanceStrategy} clustering epochs: {epoch}")
    print(f"Silhouette Score: {model.silhouetteScore}")

    axis.set_title(f"{model.distanceStrategy} {model.centroidStrategy} clustering")
    axis.set_xlabel('sepal length')
    axis.set_ylabel('petal length')
    axis.set_zlabel('petal width')

    for cIndex, cluster in enumerate(model.clusters):
        print(f"\t{cluster.name}: {cluster.silhouetteScore}")
        clusterColor: str = colors[cIndex]
        # Plot Vectors
        for vector in cluster.vectors:
            axis.scatter(vector[1], vector[2], vector[3], color=clusterColor, alpha=0.5)
        # Plot Centroid
        axis.scatter(cluster.centroid[1], cluster.centroid[2], cluster.centroid[3], color=clusterColor, marker='*', alpha=.75, s=300)

colors = ['red', 'green', 'blue']

# Prepare for visualization
figure = plt.figure(figsize=(30, 30))
grid = figure.add_gridspec(len(models), 1)
axises = grid.subplots(subplot_kw={"projection": "3d"})

# Draw clusters
for axis, model, epoch in zip(axises, models, epochs):
    Draw_Clusters(model, axis, epoch)

plt.show()
# Out:
# euclidean clustering epochs: 4
# Silhouette Score: 0.6511
# 	cluster_0: 0.5186
# 	cluster_1: 0.8624
# 	cluster_2: 0.5723
#
# euclidean clustering epochs: 3
# Silhouette Score: 0.6693
# 	cluster_0: 0.595
# 	cluster_1: 0.5545
# 	cluster_2: 0.8584
